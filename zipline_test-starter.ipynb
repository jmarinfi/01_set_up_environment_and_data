# %% [markdown]
# # Zipline Installation: Bundle Ingest & Algorithm Test

# %% [markdown]
# ## Imports and Settings

# %% [markdown]
# We don't need much here since the imports all take place in the cell where we formulate the algorithm.

# %% [markdown]
# ## Load Zipline extension

# %%
# %load_ext zipline

# %% [markdown]
# ## Ingest Data

# %%
import os
os.environ['QUANDL_API_KEY'] = 'gYATLxuA9X5z3sUVZvnA'

# !zipline ingest -b quandl
# Out:
# [2024-06-20T22:10:46-0500-INFO][zipline.data.bundles.core]
#  Ingesting quandl
# [2024-06-20T22:10:46-0500-INFO][zipline.data.bundles.quandl]
# ...
# [2024-06-20T22:15:59-0500-INFO][zipline.data.bundles.quandl]
#  Parsing raw data.
# [2024-06-20T22:16:09-0500-INFO][zipline.data.bundles.quandl]
#  Generating asset metadata.
# /home/joan/miniforge3/envs/liveproject/lib/python3.10/site-packages/zipline/data/bundles/quandl.py:106: FutureWarning: The provided callable <function min at 0x7fbcc997c430> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data = data.groupby(by="symbol").agg({"date": [np.min, np.max]})
# ...

# %% [markdown]
# ## Run a simple test algorithm

# %%
# %%zipline --start 2016-1-1 --end 2018-1-1 --benchmark-symbol AAPL
# from zipline.api import symbol, order, record
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     order(symbol('AAPL'), 10)
#     record(AAPL=data.current(symbol('AAPL'), "price"))
# Out:
# /home/joan/miniforge3/envs/liveproject/lib/python3.10/site-packages/zipline/data/data_portal.py:951: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# /home/joan/miniforge3/envs/liveproject/lib/python3.10/site-packages/zipline/finance/ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns
#                                         period_open              period_close  \
# 2016-01-04 21:00:00+00:00 2016-01-04 14:31:00+00:00 2016-01-04 21:00:00+00:00
# 2016-01-05 21:00:00+00:00 2016-01-05 14:31:00+00:00 2016-01-05 21:00:00+00:00
# ...

# %%
_.head()
# Out:
#                                         period_open              period_close  \
# 2016-01-04 21:00:00+00:00 2016-01-04 14:31:00+00:00 2016-01-04 21:00:00+00:00
# 2016-01-05 21:00:00+00:00 2016-01-05 14:31:00+00:00 2016-01-05 21:00:00+00:00
# 2016-01-06 21:00:00+00:00 2016-01-06 14:31:00+00:00 2016-01-06 21:00:00+00:00
# 2016-01-07 21:00:00+00:00 2016-01-07 14:31:00+00:00 2016-01-07 21:00:00+00:00
# 2016-01-08 21:00:00+00:00 2016-01-08 14:31:00+00:00 2016-01-08 21:00:00+00:00
#
#                            starting_cash   ending_cash       returns  \
# 2016-01-04 21:00:00+00:00   1.000000e+07  1.000000e+07  0.000000e+00
# 2016-01-05 21:00:00+00:00   1.000000e+07  9.998972e+06 -5.235500e-08
# 2016-01-06 21:00:00+00:00   9.998972e+06  9.997965e+06 -2.061350e-06
# 2016-01-07 21:00:00+00:00   9.997965e+06  9.997000e+06 -8.549243e-06
# 2016-01-08 21:00:00+00:00   9.997000e+06  9.996030e+06  1.480536e-06
#
#                            portfolio_value  longs_count  shorts_count  \
# ...
